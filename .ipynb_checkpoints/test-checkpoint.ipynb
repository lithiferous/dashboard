# %%
import imp
import numpy as np
import pandas as pd
import re
import pickle as pkl
import xlrd

# %%
from IPython.core.display import HTML
display(HTML(df.to_html()))

# %%
d = imp.load_source('dashboard', 'dashboard.py')
g = imp.load_source('gsync', 'modules/gCanvas.py')
c = imp.load_source('conf', 'config/conf.py')
r = imp.load_source('report', 'modules/reader.py')
s = imp.load_source('patch', 'modules/patcher.py')
t = imp.load_source('triggers', 'config/triggers.py')

# %%
df = r.get_report('data/report/all.xlsx', 0)

# %%
df = df[df.channel != 'Ручные рассылки']

# %%
known_names = []
for key, value in t.triggers.items():
    for df_name in value.keys():
        known_names.append(df_name)

# %%
unknown_names = []
for name in list(df.name.unique()):
    if name not in known_names:
        unknown_names.append(name)

# %%
from gspread_dataframe import *
from gspread_formatting import *

# %%
conn = g.Connection("new test dashboard")

# %%
ws = conn.get_sheet_by_name("3. Триггеры — стат. нед.")
gdf = get_as_dataframe(ws)

# %%
#, index_col=0

# %%
gdf[gdf.columns[0]][gdf[gdf.columns[0]] == 'DOI Черная пятница'].index
# Out:
# Int64Index([379], dtype='int64')

# %%
reindex_outlay(gdf, 'seasonal')
# Out:
# <function str.index>

# %%
gdf[gdf.columns[1]]
# Out:
# 0         номер недели
# 1                 даты
# 2      Трафик на сайте
# 3          Регистраций
# 4                Email
#             ...
# 468                NaN
# 469                NaN
# 470                NaN
# 471                NaN
# 472                NaN
# Name:  , Length: 473, dtype: object

# %%
, dataframe.index[dataframe.columns[1] == trigger]

# %%
def reindex_outlay(dataframe):
    for channel in t.triggers.keys():
        trigger = list(t.triggers[channel].values())[0]
        init[channel] = gdf[gdf.columns[0]][gdf[gdf.columns[0]] == trigger].index

# %%
def put_dictionary(filename, obj):
    with open(filename, 'wb') as f:
        pkl.dump(obj, f, protocol=pkl.HIGHEST_PROTOCOL)

# %%
put_dictionary('config/dictionaries/outlay3.pkl',init)

# %%
del init['start']

# %%
gdf.iloc[31:379]
# Out:
#                                   Описание триггера  \
# 31       Брошенная корзина email                NaN
# 32              Брошенных корзин                NaN
# 33                    Доставлено                NaN
# 34   Процент отработанных корзин                NaN
# 35                      Открытия                NaN
# ..                           ...                ...
# 374        Доход по атрибуции MB                NaN
# 375      Покупок по атрибуции MB                NaN
# 376     Средний чек по атрибуции                NaN
# 377           Конверсия в заказы                NaN
# 378                          NaN                NaN
#
#                                       Условия отправки  \
# 31   Положил товар в корзину \nи\nНе совершил покуп...
# 32                                                 NaN
# 33                                                 NaN
# 34                                                 NaN
# 35                                                 NaN
# ..                                                 ...
# 374                                                NaN
# 375                                                NaN
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
#
#                                       Ссылка на визуал    август Unnamed: 5  \
# 31   https://perekrestok.mindbox.ru/campaigns/4/mai...       NaN        NaN
# 32                                                 NaN     11199          0
# 33                                                 NaN      2967       2458
# 34                                                 NaN  =E35/E34        NaN
# 35                                                 NaN      1313       1052
# ..                                                 ...       ...        ...
# 374                                                NaN       NaN        NaN
# 375                                                NaN       NaN        NaN
# 376                                                NaN       NaN        NaN
# 377                                                NaN       NaN        NaN
# 378                                                NaN       NaN        NaN
#
#     Unnamed: 6 Unnamed: 7  сентябрь Unnamed: 9  ... Unnamed: 15    ноябрь  \
# 31         NaN        NaN       NaN        NaN  ...         NaN       NaN
# 32        7511      40176     42429      44804  ...       38975     38816
# 33        2958       3663      3040       3673  ...        1733      2781
# 34    =G35/G34   =H35/H34  =I35/I34   =J35/J34  ...    =P35/P34  =Q35/Q34
# 35        1162       1412      1165       1324  ...         654       928
# ..         ...        ...       ...        ...  ...         ...       ...
# 374        NaN        NaN       NaN        NaN  ...         NaN       NaN
# 375        NaN        NaN       NaN        NaN  ...         NaN       NaN
# 376        NaN        NaN       NaN        NaN  ...         NaN       NaN
# 377        NaN        NaN       NaN        NaN  ...         NaN       NaN
# 378        NaN        NaN       NaN        NaN  ...         NaN       NaN
#
#     Unnamed: 17 Unnamed: 18 Unnamed: 19            Unnamed: 20   декабрь  \
# 31          NaN         NaN         NaN                    NaN       NaN
# 32        40668       42671       61557                 121045     50437
# 33         3983        4236        8186                  12360      5664
# 34     =R35/R34    =S35/S34    =T35/T34               =U35/U34  =V35/V34
# 35         1360        1487        3014                   4547      2047
# ..          ...         ...         ...                    ...       ...
# 374         NaN         NaN         NaN                      0       NaN
# 375         NaN         NaN         NaN                      0       NaN
# 376         NaN         NaN         NaN  =iferror(U376/U377;0)       NaN
# 377         NaN         NaN         NaN  =IFERROR(U377/U370;0)       NaN
# 378         NaN         NaN         NaN                    NaN       NaN
#
#     Unnamed: 22 Unnamed: 23 Unnamed: 24
# 31          NaN         NaN         NaN
# 32        50841         NaN         NaN
# 33         5869         NaN         NaN
# 34     =W35/W34         NaN         NaN
# 35         2123         NaN         NaN
# ..          ...         ...         ...
# 374         NaN         NaN         NaN
# 375         NaN         NaN         NaN
# 376         NaN         NaN         NaN
# 377         NaN         NaN         NaN
# 378         NaN         NaN         NaN
#
# [348 rows x 25 columns]

# %%
#tmp = s.check_new_campaigns(unknown_names)
init = s.get_dictionary('config/dictionaries/outlay3.pkl')
email = gdf.iloc[init['start']:init['email']]
wp = gdf.iloc[init['email']:init['wp']]
seasonal = gdf.iloc[init['wp']:init['seasonal']]
sms = gdf.iloc[init['seasonal']:init['sms']]

# %%
online_attribution = t.online_attr

# %%
del online_attribution['subject'], online_attribution['preview_url'] 
s.put_dictionary('config/dictionaries/online_attr.pkl', online_attribution)
online_attribution = s.get_dictionary('config/dictionaries/online_attr.pkl')

# %%
def merge_dictionaries(dict1, list_ds):
    for d in list_ds:
        dict1.update(d)
    return dict1

ds = [t.triggers['email'], 
      t.triggers['wp'],
      t.triggers['seasonal'], 
      t.triggers['sms']]

# %%
cumul_d = {}
cumul_d = merge_dictionaries(cumul_d, ds)

# %%
for channel in

# %%
#df.name.map(cumul_d)

# %%
wp
# Out:
#                              Описание триггера  \
#
# Брошенная корзина Web-push                 NaN
# Брошенных корзин                           NaN
# Доставлено                                 NaN
# Процент отработанных корзин                NaN
# Открытия                                   NaN
# ...                                        ...
# Доход по атрибуции MB                      NaN
# Покупок по атрибуции MB                    NaN
# Средний чек по атрибуции                   NaN
# Конверсия в заказы                         NaN
# NaN                                        NaN
#
#                                                               Условия отправки  \
#
# Брошенная корзина Web-push   Последние 24 час не покупал. Неизвестных проду...
# Брошенных корзин                                                           NaN
# Доставлено                                                                 NaN
# Процент отработанных корзин                                                NaN
# Открытия                                                                   NaN
# ...                                                                        ...
# Доход по атрибуции MB                                                      NaN
# Покупок по атрибуции MB                                                    NaN
# Средний чек по атрибуции                                                   NaN
# Конверсия в заказы                                                         NaN
# NaN                                                                        NaN
#
#                                                               Ссылка на визуал  \
#
# Брошенная корзина Web-push   https://perekrestok.mindbox.ru/campaigns/4/mai...
# Брошенных корзин                                                           NaN
# Доставлено                                                                 NaN
# Процент отработанных корзин                                                NaN
# Открытия                                                                   NaN
# ...                                                                        ...
# Доход по атрибуции MB                                                      NaN
# Покупок по атрибуции MB                                                    NaN
# Средний чек по атрибуции                                                   NaN
# Конверсия в заказы                                                         NaN
# NaN                                                                        NaN
#
#                             август Unnamed: 5 Unnamed: 6 Unnamed: 7 сентябрь  \
#
# Брошенная корзина Web-push     NaN        NaN        NaN        NaN      NaN
# Брошенных корзин               NaN        NaN        NaN        NaN      NaN
# Доставлено                     NaN        NaN        NaN        NaN      NaN
# Процент отработанных корзин    NaN        NaN        NaN        NaN      NaN
# Открытия                       NaN        NaN        NaN        NaN      NaN
# ...                            ...        ...        ...        ...      ...
# Доход по атрибуции MB          NaN        NaN        NaN        NaN      NaN
# Покупок по атрибуции MB        NaN        NaN        NaN        NaN      NaN
# Средний чек по атрибуции       NaN        NaN        NaN        NaN      NaN
# Конверсия в заказы             NaN        NaN        NaN        NaN      NaN
# NaN                            NaN        NaN        NaN        NaN      NaN
#
#                             Unnamed: 9 Unnamed: 10  ... Unnamed: 15 ноябрь  \
#                                                     ...
# Брошенная корзина Web-push         NaN         NaN  ...         NaN    NaN
# Брошенных корзин                   NaN         NaN  ...         NaN    NaN
# Доставлено                         NaN         NaN  ...         431    807
# Процент отработанных корзин        NaN         NaN  ...         NaN    NaN
# Открытия                           NaN         NaN  ...         315    615
# ...                                ...         ...  ...         ...    ...
# Доход по атрибуции MB              NaN         NaN  ...         NaN    NaN
# Покупок по атрибуции MB            NaN         NaN  ...         NaN    NaN
# Средний чек по атрибуции           NaN         NaN  ...         NaN    NaN
# Конверсия в заказы                 NaN         NaN  ...         NaN    NaN
# NaN                                NaN         NaN  ...         NaN    NaN
#
#                             Unnamed: 17 Unnamed: 18 Unnamed: 19  \
#
# Брошенная корзина Web-push          NaN         NaN         NaN
# Брошенных корзин                    NaN         NaN         NaN
# Доставлено                         1109        1239        1718
# Процент отработанных корзин         NaN         NaN         NaN
# Открытия                            806         947        1322
# ...                                 ...         ...         ...
# Доход по атрибуции MB               NaN         NaN         NaN
# Покупок по атрибуции MB             NaN         NaN         NaN
# Средний чек по атрибуции            NaN         NaN         NaN
# Конверсия в заказы                  NaN         NaN         NaN
# NaN                                 NaN         NaN         NaN
#
#                                        Unnamed: 20 декабрь Unnamed: 22  \
#
# Брошенная корзина Web-push                     NaN     NaN         NaN
# Брошенных корзин                               NaN     NaN         NaN
# Доставлено                                    2559    1844        1995
# Процент отработанных корзин                    NaN     NaN         NaN
# Открытия                                      1984    1405        1526
# ...                                            ...     ...         ...
# Доход по атрибуции MB                            0     NaN         NaN
# Покупок по атрибуции MB                          0     NaN         NaN
# Средний чек по атрибуции     =iferror(U376/U377;0)     NaN         NaN
# Конверсия в заказы           =IFERROR(U377/U370;0)     NaN         NaN
# NaN                                            NaN     NaN         NaN
#
#                             Unnamed: 23 Unnamed: 24
#
# Брошенная корзина Web-push          NaN         NaN
# Брошенных корзин                    NaN         NaN
# Доставлено                          NaN         NaN
# Процент отработанных корзин         NaN         NaN
# Открытия                            NaN         NaN
# ...                                 ...         ...
# Доход по атрибуции MB               NaN         NaN
# Покупок по атрибуции MB             NaN         NaN
# Средний чек по атрибуции            NaN         NaN
# Конверсия в заказы                  NaN         NaN
# NaN                                 NaN         NaN
#
# [76 rows x 24 columns]

# %%
def append_campaign(dataframe, channel):
    for trigger, campaign in t.triggers[channel].items():
        dataframe = dataframe.append(pd.Series(name = campaign))
        for key, attribution in online_attribution.items():
            dataframe = dataframe.append(pd.Series(name = attribution))
            dataframe.iloc[-1, self.limit] = mb_df.loc[df.name == trigger, key]

# %%
def extend_dataframe(self, mb_df):
    """Inserts new rows for new campaigns to gspread-dataframe
    -> mb_df: dataframe from MindBox report
    """
    init = s.get_dictionary('config/dictionaries/outlay3.pkl')
    email = gdf.iloc[init['start']:init['email']]
    wp = gdf.iloc[init['email']:init['wp']]
    seasonal = gdf.iloc[init['wp']:init['seasonal']]
    sms = gdf.iloc[init['seasonal']:init['sms']]
    
    channel_dfs = [email, wp, seasonal, sms]
    del init['start']
    
    result_df = pd.DataFrame()
    for channel, dataframe in dict(zip(init.values(), channel_dfs)):
        for trigger, campaign in t.triggers[channel].items():
            dataframe = dataframe.append(pd.Series(name = campaign))
            for key, attribution in online_attribution.items():
                dataframe = dataframe.append(pd.Series(name = attribution))
                dataframe.iloc[-1, self.limit] = mb_df.loc[df.name == trigger, key]

        result_df = result_df.append(dataframe)
    return result_df
# Out:
# 48    6507
# Name: delivered, dtype: int64
# 48    2366
# Name: opened, dtype: int64
# 48    0.363608
# Name: open_rate, dtype: float64
# 48    600
# Name: clicked, dtype: int64
# 48    0.092208
# Name: click_rate, dtype: float64
# 48    0.253593
# Name: CTR, dtype: float64
# 48    5
# Name: unfollowed, dtype: int64
# 48    0.000768
# Name: unfollow_rate, dtype: float64
# 48    713121
# Name: revenue, dtype: int64
# 48    173
# Name: orders, dtype: int64
# 48    4122.089711
# Name: avg_bill, dtype: float64
# 48    0.026587
# Name: order_conversion, dtype: float64

# %%
email
# Out:
#                              Описание триггера  \
#
# Брошенная корзина email                    NaN
# Брошенных корзин                           NaN
# Доставлено                                 NaN
# Процент отработанных корзин                NaN
# Открытия                                   NaN
# ...                                        ...
# Средний чек по атрибуции                   NaN
# Конверсия в заказы                         NaN
# NaN                                        NaN
# Брошенная корзина email                    NaN
# Брошенная корзина email                    NaN
#
#                                                               Условия отправки  \
#
# Брошенная корзина email      Положил товар в корзину \nи\nНе совершил покуп...
# Брошенных корзин                                                           NaN
# Доставлено                                                                 NaN
# Процент отработанных корзин                                                NaN
# Открытия                                                                   NaN
# ...                                                                        ...
# Средний чек по атрибуции                                                   NaN
# Конверсия в заказы                                                         NaN
# NaN                                                                        NaN
# Брошенная корзина email                                                    NaN
# Брошенная корзина email                                                    NaN
#
#                                                               Ссылка на визуал  \
#
# Брошенная корзина email      https://perekrestok.mindbox.ru/campaigns/4/mai...
# Брошенных корзин                                                           NaN
# Доставлено                                                                 NaN
# Процент отработанных корзин                                                NaN
# Открытия                                                                   NaN
# ...                                                                        ...
# Средний чек по атрибуции                                                   NaN
# Конверсия в заказы                                                         NaN
# NaN                                                                        NaN
# Брошенная корзина email                                                    NaN
# Брошенная корзина email                                                    NaN
#
#                                август Unnamed: 5 Unnamed: 6 Unnamed: 7  \
#
# Брошенная корзина email           NaN        NaN        NaN        NaN
# Брошенных корзин                11199          0       7511      40176
# Доставлено                       2967       2458       2958       3663
# Процент отработанных корзин  =E35/E34        NaN   =G35/G34   =H35/H34
# Открытия                         1313       1052       1162       1412
# ...                               ...        ...        ...        ...
# Средний чек по атрибуции          NaN        NaN        NaN        NaN
# Конверсия в заказы                NaN        NaN        NaN        NaN
# NaN                               NaN        NaN        NaN        NaN
# Брошенная корзина email           NaN        NaN        NaN        NaN
# Брошенная корзина email           NaN        NaN        NaN        NaN
#
#                              сентябрь Unnamed: 9 Unnamed: 10  ... Unnamed: 15  \
#                                                               ...
# Брошенная корзина email           NaN        NaN         NaN  ...         NaN
# Брошенных корзин                42429      44804       45207  ...       38975
# Доставлено                       3040       3673        3767  ...        1733
# Процент отработанных корзин  =I35/I34   =J35/J34    =K35/K34  ...    =P35/P34
# Открытия                         1165       1324        1379  ...         654
# ...                               ...        ...         ...  ...         ...
# Средний чек по атрибуции          NaN        NaN         NaN  ...         NaN
# Конверсия в заказы                NaN        NaN         NaN  ...         NaN
# NaN                               NaN        NaN         NaN  ...         NaN
# Брошенная корзина email           NaN        NaN         NaN  ...         NaN
# Брошенная корзина email           NaN        NaN         NaN  ...         NaN
#
#                                ноябрь Unnamed: 17 Unnamed: 18 Unnamed: 19  \
#
# Брошенная корзина email           NaN         NaN         NaN         NaN
# Брошенных корзин                38816       40668       42671       61557
# Доставлено                       2781        3983        4236        8186
# Процент отработанных корзин  =Q35/Q34    =R35/R34    =S35/S34    =T35/T34
# Открытия                          928        1360        1487        3014
# ...                               ...         ...         ...         ...
# Средний чек по атрибуции          NaN         NaN         NaN         NaN
# Конверсия в заказы                NaN         NaN         NaN         NaN
# NaN                               NaN         NaN         NaN         NaN
# Брошенная корзина email           NaN         NaN         NaN         NaN
# Брошенная корзина email           NaN         NaN         NaN         NaN
#
#                                        Unnamed: 20                декабрь  \
#
# Брошенная корзина email                        NaN                    NaN
# Брошенных корзин                            121045                  50437
# Доставлено                                   12360                   5664
# Процент отработанных корзин               =U35/U34               =V35/V34
# Открытия                                      4547                   2047
# ...                                            ...                    ...
# Средний чек по атрибуции                =U300/U301                      0
# Конверсия в заказы           =IFERROR(U301/U292;0)  =IFERROR(V301/V292;0)
# NaN                                            NaN                    NaN
# Брошенная корзина email                        NaN                    NaN
# Брошенная корзина email                        NaN                    NaN
#
#                                        Unnamed: 22 Unnamed: 23 Unnamed: 24
#
# Брошенная корзина email                        NaN         NaN         NaN
# Брошенных корзин                             50841         NaN         NaN
# Доставлено                                    5869         NaN         NaN
# Процент отработанных корзин               =W35/W34         NaN         NaN
# Открытия                                      2123         NaN         NaN
# ...                                            ...         ...         ...
# Средний чек по атрибуции                         0         NaN         NaN
# Конверсия в заказы           =IFERROR(W301/W292;0)         NaN         NaN
# NaN                                            NaN         NaN         NaN
# Брошенная корзина email                        NaN         NaN         NaN
# Брошенная корзина email                        NaN         NaN         NaN
#
# [274 rows x 24 columns]

# %%
email.iloc[-1,-2]
# Out:
# nan

# %%
# Out:
# {'delivered': 'Доставлено',
#  'opened': 'Открытия',
#  'open_rate': 'OR',
#  'clicked': 'Кликов',
#  'click_rate': 'CR',
#  'ctor': 'CTR',
#  'unfollowed': 'Отписок',
#  'unfollow_rate': 'UR',
#  'revenue': 'Доход по атрибуции MB',
#  'orders': 'Покупок по атрибуции MB',
#  'avg_bill': 'Средний чек по атрибуции',
#  'order_conversion': 'Конверсия в заказы'}

# %%
tmp
# Out:
# {'email': 6, 'seasonal': 2, 'wp': 0}

# %%
#set_with_dataframe(conn.get_sheet_by_name("Лист10"), df)

# %%
vals = df[df.columns[0]].unique()

# %%
known_names = []
for key, value in t.triggers.items():
    for df_name in value.values():
        known_names.append(df_name)

# %%
boolcol = []
for val in df[df.columns[0]]:
    boolcol.append(val in known_names)

# %%
df.loc[boolcol]
# Out:
#                                                         Описание триггера  \
# 31                             Брошенная корзина email                NaN
# 48                                 Welcome 1 new email                NaN
# 63                     Брошенный просмотр товара email                NaN
# 77                  Брошенный просмотр категории email                NaN
# 91                                  Неделя до ДР email                NaN
# 106                                  Реактивация email                NaN
# 121                     Товар появился в наличии email                NaN
# 135                    Напоминание о промокоде А email                NaN
# 149                    Напоминание о промокоде В email                NaN
# 163                               Отток Активные email                NaN
# 177                          trig_water_reminder email                NaN
# 191                      Напоминание о промокоде NEW_2                NaN
# 205                      Напоминание о промокоде NEW_3                NaN
# 219                                         Додо Пицца                NaN
# 233                                   Мираторг + Tefal                NaN
# 247                             DOI Интерактивный тест                NaN
# 261                     DOI Интерактивный тест Спасибо                NaN
# 275  Пожалуйста, подтвердите подписку (Facebook Leads)                NaN
# 289           Ваш промокод уже здесь! (Facebook Leads)                NaN
# 303                         Брошенная корзина Web-push                NaN
# 317                 Брошенный просмотр товара Web-push                NaN
# 330              Брошенный просмотр категории Web-push                NaN
# 343                            water_reminder Web-push                NaN
# 355                  Товар появился в наличии Web-push                NaN
# 367                      trig_subscribe_email Web-push                NaN
# 379                                 DOI Черная пятница                NaN
# 393                         DOI Черная пятница Спасибо                NaN
# 407                                           DOI Елки                NaN
# 421                                       Елки Спасибо                NaN
# 435                                     Копия Елка SMS                NaN
# 435         NaN         NaN         NaN         NaN     NaN         NaN
#
#     Unnamed: 23 Unnamed: 24
# 31          NaN         NaN
# 48          NaN         NaN
# 63          NaN         NaN
# 77          NaN         NaN
# 91          NaN         NaN
# 106         NaN         NaN
# 121         NaN         NaN
# 135         NaN         NaN
# 149         NaN         NaN
# 163         NaN         NaN
# 177         NaN         NaN
# 191         NaN         NaN
# 205         NaN         NaN
# 219         NaN         NaN
# 233         NaN         NaN
# 247         NaN         NaN
# 261         NaN         NaN
# 275         NaN         NaN
# 289         NaN         NaN
# 303         NaN         NaN
# 317         NaN         NaN
# 330         NaN         NaN
# 343         NaN         NaN
# 355         NaN         NaN
# 367         NaN         NaN
# 379         NaN         NaN
# 393         NaN         NaN
# 407         NaN         NaN
# 421         NaN         NaN
# 435         NaN         NaN
#
# [30 rows x 25 columns]

# %%
outlay = {'email':302,
          'wp':378,
          'seasonal':434,
          'sms':437}

# %%
s.put_dictionary('config/dictionaries/outlay3.pkl', outlay)

# %%
df = pd.read_excel('data/report/all.xlsx')
ind = df.loc[df.iloc[:,0] == 'Бренд'].index[0]
df = df.iloc[ind+2:, 4:-1]
header = ['name', 'channel', 'subject', 'preview_url',
          'sent', 'delivered', 'deliver_rate', 'opened',
          'open_rate', 'clicked', 'click_rate', 'CTR',
          'unfollowed', 'unfollow_rate', 'revenue', 'orders',
          'avg_bill', 'order_conversion']
df.columns = header
df[['sent', 'delivered', 'opened', 'clicked',
    'unfollowed', 'revenue', 'orders']] = \
df[['sent', 'delivered', 'opened', 'clicked',
    'unfollowed', 'revenue', 'orders']].astype('int64')
df[['deliver_rate', 'open_rate', 'click_rate', 'CTR',
    'unfollow_rate', 'avg_bill', 'order_conversion']] = \
df[['deliver_rate', 'open_rate', 'click_rate', 'CTR',
    'unfollow_rate', 'avg_bill', 'order_conversion']].astype('float64')
#return df

# %%
names = df[(df.name != '(Для тестов)') & (df.sent != 0)]['name'].unique()
# Out:
# array(['Триггер 1. Брошенная корзина', 'Триггер_2_Брошенный просмотр',
#        'Триггер_4 "Брошенный просмотр категории"',
#        'WP "Брошенная корзина"',
#        'Триггер 17. Брошенная корзина с оффером',
#        'Welcome 1. Приветствие и промокод NEW',
#        'Триггер_3_Напоминание о промокоде A',
#        'Триггер_3_Напоминание о промокоде В',
#        'Триггер_12_Напоминание о промокоде NEW_2',
#        'Триггер_13_Напоминание о промокоде NEW_3',
#        'Ваш промокод уже здесь! (Facebook Leads)', 'NY landing 2020 DOI',
#        'NY landing 2020 DOI promocode', 'Триггер_5 "Реактивация"',
#        'Триггер_7_Товар появился в наличии', 'Email Отток Активные',
#        'Email trig_water_reminder', 'WP water_reminder',
#        'Триггер_14_ "Онлайн дешевле"', 'Триггер Мираторг + Tefal',
#        'DOI Ёлки', 'Ёлки Спасибо', 'Копия Ёлка SMS',
#        'Письмо с промокодом Babyblog (для новых)', 'DOI BabyBlog',
#        'Персональный промокод на скидку — в письме! 🤤', 'SMS с опросом',
#        'SMS без оффера', 'SMS с оффером', '171219_elki',
#        '18122019_🎁Самое главное в подарке — это…', 'sms beauty_181219',
#        'Для вас сюрприз! Откройте письмо 😉',
#        'Мы снизили цены на елки! Скидки до 50%'], dtype=object)

# %%
def prepare_campaign_names(names):
    if 'Триггер' in name:
        txt = re.findall(r'[А-я]+', data)

# %%
df.iloc[ind+2:]
# Out:
#       Unnamed: 0           Unnamed: 1 Unnamed: 2           Unnamed: 3  \
# 48   Perekrestok   Брошенные действия   без тэга  2019-07-05 11:50:15
# 49   Perekrestok   Брошенные действия   без тэга  2019-07-11 13:50:41
# 50   Perekrestok   Брошенные действия   без тэга  2019-08-12 21:43:57
# 51   Perekrestok   Брошенные действия   без тэга  2019-09-18 14:10:19
# 52   Perekrestok   Брошенные действия   без тэга  2019-09-27 12:49:21
# ..           ...                  ...        ...                  ...
# 111  Perekrestok  Черная пятница 2019   без тэга  2019-11-08 16:21:57
# 112  Perekrestok   Интерактивный тест   без тэга  2019-11-15 12:52:11
# 113  Perekrestok   Интерактивный тест   без тэга  2019-11-15 14:16:17
# 114  Perekrestok               Ивенты   без тэга  2019-12-05 17:51:21
# 115  Perekrestok               Ивенты   без тэга  2019-12-13 12:16:10
#
#                                    Unnamed: 4               Unnamed: 5  \
# 48               Триггер 1. Брошенная корзина  Автоматические рассылки
# 49               Триггер_2_Брошенный просмотр  Автоматические рассылки
# 50   Триггер_4 "Брошенный просмотр категории"  Автоматические рассылки
# 51                               (Для тестов)  Автоматические рассылки
# 52                     WP "Брошенная корзина"  Автоматические рассылки
# ..                                        ...                      ...
# 111                DOI Черная пятница Спасибо  Автоматические рассылки
# 112                    DOI Интерактивный тест  Автоматические рассылки
# 113            DOI Интерактивный тест Спасибо  Автоматические рассылки
# 114     Начинаем подготовку к Новому году! 😍🌟          Ручные рассылки
# 115   А вы уже написали список Деду Морозу?🎅🏻          Ручные рассылки
#
#                                             Unnamed: 6  \
# 48   @{if IsEmpty(Recipient.OnlyStandardFirstName)}...
# 49              Хотите добавить товары в свою корзину?
# 50                                 Вы что-то искали? 🤔
# 51                                                Тест
# 52                                            Без темы
# ..                                                 ...
# 111                            Спасибо за регистрацию!
# 112                             Ваш промокод в письме!
# 113                             Ваш промокод в письме!
# 114              Начинаем подготовку к Новому году! 😍🌟
# 115            А вы уже написали список Деду Морозу?🎅🏻
#
#                                             Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 48   https://email-services.mindbox.ru/v1/projects/...       6511       6507
# 49   https://email-services.mindbox.ru/v1/projects/...        314        314
# 50   https://email-services.mindbox.ru/v1/projects/...       2516       2513
# 51   https://email-services.mindbox.ru/v1/projects/...          2          2
# 52                                             (blank)       2392       2392
# ..                                                 ...        ...        ...
# 111  https://email-services.mindbox.ru/v1/projects/...          0          0
# 112  https://email-services.mindbox.ru/v1/projects/...          0          0
# 113  https://email-services.mindbox.ru/v1/projects/...          0          0
# 114  https://email-services.mindbox.ru/v1/projects/...          0          0
# 115  https://email-services.mindbox.ru/v1/projects/...          0          0
#
#      ... Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  Unnamed: 17  \
# 48   ...         600   0.0922084    0.253593           5  0.000768403
# 49   ...          20   0.0636943     0.15873           1   0.00318471
# 50   ...         132   0.0525269    0.169666           4   0.00159172
# 51   ...           0           0           0           0            0
# 52   ...          84   0.0351171   0.0457018           0            0
# ..   ...         ...         ...         ...         ...          ...
# 111  ...           0           0           0           0            0
# 112  ...           0           0           0           0            0
# 113  ...           0           0           0           0            0
# 114  ...           0           0           0           0            0
# 115  ...           0           0           0           0            0
#
#     Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22
# 48       713122         173     4122.09   0.0265868     109.593
# 49      16734.3           4     4183.58   0.0127389      53.294
# 50       103441          25     4137.65  0.00994827     41.1625
# 51            0           0           0           0           0
# 52      53795.1          14     3842.51  0.00585284     22.4896
# ..          ...         ...         ...         ...         ...
# 111           0           0           0           0           0
# 112           0           0           0           0           0
# 113           0           0           0           0           0
# 114           0           0           0           0           0
# 115           0           0           0           0           0
#
# [68 rows x 23 columns]

# %%
#df = pd.read_excel('data/report/all.xlsx', sheet_name='Свод. данные (online)')
df = get_report('data/report/all.xlsx', 'Свод. данные (online + offline)')

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')

# %%
s = """brand 	campaign 	tag 	date 	name 	channel 	subject 	preview_url 	sent 	delivered 	... 	clicked 	click_rate 	ctor 	unfollowed 	unfollow_rate 	revenue 	orders 	avg_bill 	order_conversion 	revenue_per_user"""

# %%
' '.join(s.split(' 	'))
# Out:
# 'brand campaign tag date name channel subject preview_url sent delivered ... clicked click_rate ctor unfollowed unfollow_rate revenue orders avg_bill order_conversion revenue_per_user'

# %%
df.columns
# Out:
# Index(['brand', 'campaign', 'tag', 'date', 'name', 'channel', 'subject',
#        'preview_url', 'sent', 'delivered', 'delivery_rate', 'opened',
#        'open_rate', 'clicked', 'click_rate', 'ctor', 'unfollowed',
#        'unfollow_rate', 'revenue', 'orders', 'avg_bill', 'order_conversion',
#        'revenue_per_user'],
#       dtype='object')

# %%
df[(df.sent != 0) & (df.channel == 'Ручные рассылки')]
# Out:
#            brand               campaign       tag                date  \
# 79   Perekrestok  A/B тест для Активных  без тэга 2019-12-16 19:01:20
# 80   Perekrestok  A/B тест для Активных  без тэга 2019-12-16 19:01:20
# 83   Perekrestok    Регулярные рассылки  без тэга 2019-12-17 19:00:50
# 84   Perekrestok    Регулярные рассылки  без тэга 2019-12-18 17:31:01
# 85   Perekrestok    Регулярные рассылки  без тэга 2019-12-18 19:38:30
# 105  Perekrestok                NY 2020  без тэга 2019-12-23 19:51:03
#
#                                          name          channel  \
# 79                             SMS без оффера  Ручные рассылки
# 80                              SMS с оффером  Ручные рассылки
# 83                                171219_elki  Ручные рассылки
# 84   18122019_🎁Самое главное в подарке — это…  Ручные рассылки
# 85                          sms beauty_181219  Ручные рассылки
# 105    Мы снизили цены на елки! Скидки до 50%  Ручные рассылки
#
#                                     subject  \
# 79                                 Без темы
# 80                                 Без темы
# 83       🌲Пушистые елки из России и Дании 🌲
# 84          🎁Самое главное в подарке — это…
# 85                                 Без темы
# 105  Мы снизили цены на елки! Скидки до 50%
#
#                                            preview_url    sent  delivered  \
# 79                                             (blank)     227        203
# 80                                             (blank)     233        205
# 83   https://email-services.mindbox.ru/v1/projects/...  200642     198025
# 84   https://email-services.mindbox.ru/v1/projects/...  200958     198561
# 85                                             (blank)   21619      21189
# 105  https://email-services.mindbox.ru/v1/projects/...  202931     200573
#
#      ...  clicked  click_rate      ctor  unfollowed  unfollow_rate  \
# 79   ...        0    0.000000  0.000000           0       0.000000
# 80   ...        0    0.000000  0.000000           0       0.000000
# 83   ...     5507    0.027810  0.197193         251       0.001268
# 84   ...     5857    0.029497  0.159491         418       0.002105
# 85   ...        0    0.000000  0.000000           0       0.000000
# 105  ...     5941    0.029620  0.166597         249       0.001241
#
#         revenue  orders     avg_bill  order_conversion  revenue_per_user
# 79         0.00       0     0.000000          0.000000          0.000000
# 80         0.00       0     0.000000          0.000000          0.000000
# 83   1713695.83     393  4360.549186          0.001985          8.653937
# 84   2903501.53     665  4366.167714          0.003349         14.622718
# 85         0.00       0     0.000000          0.000000          0.000000
# 105  1447405.40     368  3933.166848          0.001835          7.216352
#
# [6 rows x 23 columns]

# %%
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>brand</th>
#       <th>campaign</th>
#       <th>tag</th>
#       <th>date</th>
#       <th>name</th>
#       <th>channel</th>
#       <th>subject</th>
#       <th>preview_url</th>
#       <th>sent</th>
#       <th>delivered</th>
#       <th>delivery_rate</th>
#       <th>opened</th>
#       <th>open_rate</th>
#       <th>clicked</th>
#       <th>click_rate</th>
#       <th>ctor</th>
#       <th>unfollowed</th>
#       <th>unfollow_rate</th>
#       <th>revenue</th>
#       <th>orders</th>
#       <th>avg_bill</th>
#       <th>order_conversion</th>
#       <th>revenue_per_user</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>48</th>
#       <td>Perekrestok</td>
#       <td>Брошенные действия</td>
#       <td>без тэга</td>
#       <td>2019-07-05 11:50:15</td>
#       <td>Триггер 1. Брошенная корзина</td>
#       <td>Автоматические рассылки</td>
#       <td>@{if IsEmpty(Recipient.OnlyStandardFirstName)} @{set theme1 = "Вы готовы завершить заказ?"}@{set theme2 = "Пожалуйста, завершите заказ"}@{set theme3 = "Перейдите в корзину и завершите заказ"}@{ else }@{set theme1 = Recipient.OnlyStandardFirstName &amp; ", вы готовы завершить заказ?"}@{set theme2 = Recipient.OnlyStandardFirstName &amp; ", пожалуйста, завершите заказ"}@{set theme3 = Recipient.OnlyStandardFirstName &amp; ", перейдите в корзину и завершите заказ"}@{ end if }${ChooseRandomText("Ваши товары ждут в корзине","Заберите их, пожалуйста, к себе домой!","В корзине вас ждут товары, которые хотят попасть домой","Все решено?","Хороший выбор!","Не откладывайте на завтра то, что можно сделать сегодня!","Посмотрите, вы ничего не забыли?",theme1, theme2, theme3)}</td>
#       <td>https://email-services.mindbox.ru/v1/projects/1309/email/previewtemplate/?uniqueKey=2305843010287435776&amp;hash=AB1563AC2DFD3E45AFCD26E1A400232D8023C0D6&amp;format=Html</td>
#       <td>6511</td>
#       <td>6507</td>
#       <td>0.999386</td>
#       <td>2366</td>
#       <td>0.363608</td>
#       <td>600</td>
#       <td>0.092208</td>
#       <td>0.253593</td>
#       <td>5</td>
#       <td>0.000768</td>
#       <td>713121.52</td>
#       <td>173</td>
#       <td>4122.089711</td>
#       <td>0.026587</td>
#       <td>109.592980</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>
# 105  Мы снизили цены на елки! Скидки до 50%
#
#                                            preview_url    sent  delivered  \
# 79                                             (blank)     227        203
# 80                                             (blank)     233        205
# 85                                             (blank)   21619      21189
# 105  https://email-services.mindbox.ru/v1/projects/...  202931     200573
#
#      ...  clicked  click_rate      ctor  unfollowed  unfollow_rate    revenue  \
# 79   ...        0     0.00000  0.000000           0       0.000000        0.0
# 80   ...        0     0.00000  0.000000           0       0.000000        0.0
# 85   ...        0     0.00000  0.000000           0       0.000000        0.0
# 105  ...     5941     0.02962  0.166597         249       0.001241  1447405.4
#
#      orders     avg_bill  order_conversion  revenue_per_user
# 79      0.0     0.000000          0.000000          0.000000
# 80      0.0     0.000000          0.000000          0.000000
# 85      0.0     0.000000          0.000000          0.000000
# 105   368.0  3933.166848          0.001835          7.216352
#
# [4 rows x 23 columns]

# %%
df.iloc[df.loc[df.iloc[:,0] == 'Бренд'].index[0]]
# Out:
# Unnamed: 0                               Бренд
# Unnamed: 1                            Кампания
# Unnamed: 2                                 Тэг
# Unnamed: 3                Дата старта рассылки
# Unnamed: 4                   Название рассылки
# Unnamed: 5                               Канал
# Unnamed: 6                         Тема письма
# Unnamed: 7                     Ссылка на макет
# Unnamed: 8                    Отправлено писем
# Unnamed: 9                    Доставлено писем
# Unnamed: 10                     % Доставленных
# Unnamed: 11                Количество открытий
# Unnamed: 12                          Open rate
# Unnamed: 13                  Количество кликов
# Unnamed: 14                         Click rate
# Unnamed: 15                             CTOR
# Unnamed: 16                  Запрошена отписка
# Unnamed: 17              % Запросов на отписку
# Unnamed: 18                 Доход по атрибуции
# Unnamed: 19    Количество заказов по атрибуции
# Unnamed: 20           Средний чек по атрибуции
# Unnamed: 21                 Конверсия в заказы
# Unnamed: 22                Доход на получателя
# Name: 46, dtype: object

# %%
# Out:
# 46

# %%
df = df[df.channel != 'Ручные рассылки']
df = df[['name', 'sent', 'delivered', 'opened', 'clicked', 'unfollowed', 'revenue', 'orders']]

# %%
df = df[df.sent!=0]

# %%
#res = check_seasonality(list(df.name.loc[~df.name.map(t.triggers).notna()]))

# %%
res
# Out:
# ['NY landing 2020 DOI', 'NY landing 2020 DOI promocode']

# %% [markdown]
#  * Принципиально ли их иметь разбитыми на категории
#  * Обработка сезонных триггеров

# %%
def check_seasonality(campaigns):
    maxlen = len(campaigns)
    print("""Проверьте, является ли компания сезонной для {n} новых;
    Нажмите только 'Enter', если компания не является сезонной
    Введите 1, если компания является сезонной
    Введите 0 для сброса ввода и возврату к первому значению""".format(n=maxlen))
    res = []
    i = 0
    while(i != maxlen):
        v = input(campaigns[i]+': ')
        if v == '':
             i+=1
        elif v == '1':
            res.append(campaigns[i]); i+=1
        elif v == '0':
            return check_seasonality(campaigns)
        else:
            i -= 1
            print("Повторите ввод в согласии с инструкцией\n")            
    return res

# %%
check_seasonality

# %%
# %%time
# !python dashboard.py -p 1 -r "data/report.xlsx" -o 'data/orders.csv' -c 'data/client_groups.f'
# Out:
# dashboard.py:3: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# CPU times: user 112 ms, sys: 12 ms, total: 124 ms
# Wall time: 5.96 s
