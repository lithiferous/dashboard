# %%
import imp
import numpy as np
import pandas as pd
import pickle as pkl
import re

# %%
d = imp.load_source('dashboard', 'dashboard.py')
g = imp.load_source('gsync', 'modules/gCanvas.py')
c = imp.load_source('conf', 'config/conf.py')
r = imp.load_source('report', 'modules/reader.py')
s = imp.load_source('patch', 'modules/patcher.py')
t = imp.load_source('triggers', 'config/triggers.py')

# %%
df = r.get_report('all.xlsx', 0)
df = df[df.channel != 'Ручные рассылки']

# %%
from gspread_dataframe import *
from gspread_formatting import *

# %%
conn = g.Connection("new test dashboard")
name = "3. Триггеры — стат. нед."
ws = conn.get_sheet_by_name(name)
gdf = get_as_dataframe(ws, index_col = 0)

# %%
online_attr = s.get_dictionary('config/dictionaries/online_attr.pkl')

# %%
patcher = s.Patcher(df, 2, 24, gdf)
# Out:
# Определите категорию кампании для 9 новых:
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> Триггер 17. Брошенная корзина с оффером:
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
# Брошенная корзина с оффером
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> NY landing 2020 DOI:
# 2
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> NY landing 2020 DOI promocode:
# 2
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> Триггер_14_ "Онлайн дешевле":
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
# Онлайн дешевле
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> Письмо с промокодом Babyblog (для новых):
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> DOI BabyBlog:
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> Персональный промокод на скидку — в письме! 🤤:
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> SMS с опросом:
# 3
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> Для вас сюрприз! Откройте письмо 😉:
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-7cf74b2929ac> in <module>
# ----> 1 patcher = s.Patcher(df, 2, 24, gdf)
#
# ~/projects/work/dashboard/modules/patcher.py in __init__(self, df, type, limit, gdf)
#      32         self.d = get_dictionary('data/cell_dicts.pkl')
#      33         self.t = triggers
# ---> 34         self.patch = self.switch()
#      35
#      36     def switch(self):
#
# ~/projects/work/dashboard/modules/patcher.py in switch(self)
#      36     def switch(self):
#      37         """Performs tabwise patch enrichment"""
# ---> 38         return getattr(self, self.methods[self.type])()
#      39
#      40     def get_group_increments(self):
#
# ~/projects/work/dashboard/modules/patcher.py in get_campaigns_online(self)
#     177         new_campaigns = list(self.df.name.loc[~self.df.name.isin(actual_values)])
#     178         create_new_campaigns(self.gdf, new_campaigns, self.limit - 1)
# --> 179         self.gdf = update_campaigns(self.df, self.gdf, self.limit - 1)
#     180
#     181         return build_patch(self.gdf)
#
# ~/projects/work/dashboard/modules/patcher.py in update_campaigns(df, gdf, max_cols)
#     146             for channel in triggers.triggers.keys():
#     147                 for trigger, campaign in triggers.triggers[channel].items():
# --> 148                     campaign_index = gdf[gdf.columns[0]].loc[gdf[gdf.columns[0]] == campaign].index[0]
#     149                     for index, row in gdf.iloc[campaign_index:].iterrows():
#     150                         if pd.isnull(row[0]):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4278         if is_scalar(key):
#    4279             key = com.cast_scalar_indexer(key)
# -> 4280             return getitem(key)
#    4281
#    4282         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
outlay=s.get_dictionary('config/dictionaries/outlay3.pkl')

# %%
def reindex_outlay(df):
    """Update start indices for each channel email/wp/seasonal/sms
    -> df: dataframe from gspread get_as_dataframe
    """
    df = df.reset_index()
    for channel in t.triggers.keys():
        trigger = list(t.triggers[channel].values())[0]
        outlay[channel] = df[df.columns[0]][df[df.columns[0]] == trigger].index[0]
    s.put_dictionary('config/dictionaries/outlay3.pkl', outlay)
reindex_outlay(gdf)

# %%
s.get_dictionary('config/dictionaries/outlay3.pkl')
# Out:
# {'email': 31, 'wp': 303, 'seasonal': 379, 'sms': 435}

# %%
import gspread

# %%
def build_patch(df):
    """Returns df as a list of cells to patch for gspread update"""
    row=1
    col=1
    y, x = df.shape
    updates = []
    values = []
    for value_row in df.values:
        values.append(value_row)
    for y_idx, value_row in enumerate(values):
        for x_idx, cell_value in enumerate(value_row):
            updates.append(gspread.models.Cell(y_idx+row,
                                               x_idx+col,
                                               cell_value))
    return updates

# %%
#build_patch(patcher.gdf)

# %%
patc.iloc[519:,0].values
# Out:
# array(['Копия Елка SMS', 'Доставлено', 'NY landing 2020 DOI',
#        'Доставлено', 'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок',
#        'UR', 'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'NY landing 2020 DOI promocode', 'Доставлено', 'Открытия', 'OR',
#        'Кликов', 'CR', 'CTR', 'Отписок', 'UR', 'Доход по атрибуции MB',
#        'Покупок по атрибуции MB', 'Средний чек по атрибуции',
#        'Конверсия в заказы', nan, 'SMS с опросом', 'Доставлено',
#        'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок', 'UR',
#        'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan],
#       dtype=object)

# %%
mask = patcher.gdf[patcher.gdf.columns[0]].notna()
grps = pd.Series([*zip(mask.cumsum(), mask)], patcher.gdf.index)
tmp = patcher.gdf.groupby(grps).filter(lambda d: len(d) <= 2)

# %% [markdown]
# * global traffic
# * get main через named tuple
# * написать метод get_as_dataframe для gCanvas
#     * *перед удалением всех 4 групп, нужно реализовать суммы по группам*
#     * *рекурсивный обход df с печатью формата*

# %%
main_={'Доставлено':'Доставлено',
       'OR':'OR',
      'CR':'CR',
      'Доход по атрибуции MB':'Выручка',
      'Заказов':'Покупок по атрибуции MB',
      'Заказов':'Заказов от трафика',
      'Конверсия в заказы':'Конверсия в заказы',}

# %%
from collections import namedtuple
Point = namedtuple('group', [
        'Доставлено',
        'OR',
        'CR',
        'Выручка',
        'Заказов',
        'Заказов от трафика',
        'Конверсия в заказы',])
# Out:
# Доставлено
# Открытия
# OR
# Кликов
# CR
# CTR
# Отписок
# UR
# Доход по атрибуции MB
# Покупок по атрибуции MB
# Средний чек по атрибуции
# Конверсия в заказы

# %%
def get_index(chnl):
    if chnl == 'email':
        return 6
    elif chnl == 'wp':
        return 16
    elif chnl == 'seasonal':
        return 24
    else : return None

# %%
main_=[] 
for channel in t.triggers.keys():
        trigger = list(t.triggers[channel].values())[0]
        outlay[channel] = df[df.columns[0]][df[df.columns[0]] == trigger].index[0]

# %%
s.put_dictionary('config/dictionaries/outlay3.pkl', outlay)

# %%
main_={'Доставлено':'Доставлено',
       'OR':'OR',
      'CR':'CR',
      'Доход по атрибуции MB':'Выручка',
      'Заказов':'Покупок по атрибуции MB',
      'Заказов':'Заказов от трафика',
      'Конверсия в заказы':'Конверсия в заказы',}

# %%
def main_tbl_aggregator(df, attr, max_cols):
    n = 0
    res = 0
    if attr in ['Доставлено',  'Доход по атрибуции MB', 'Покупок по атрибуции MB',]:
        res+=df.loc[df.name == attr, max_cols]
    elif attr in ['OR','CR', 'Конверсия в заказы']:

# %%
z = patcher.gdf.reset_index()

# %%
def get_campaign_info(df, name, column):
    """Locates specific value for named campaign"""
    try: res = df.loc[df.name == name, column].values[0]
    except: res = 0
    return res

# %%
df = r.get_report('data/report/all.xlsx', 0)
df = df[df.channel != 'Ручные рассылки']

# %%
df.columns = df.columns.to_series().replace(online_attr)

# %%
df.columns
# Out:
# Index(['name', 'channel', 'subject', 'preview_url', 'sent', 'Доставлено',
#        'deliver_rate', 'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок',
#        'UR', 'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы'],
#       dtype='object')

# %%
online_attr
# Out:
# {'delivered': 'Доставлено',
#  'opened': 'Открытия',
#  'open_rate': 'OR',
#  'clicked': 'Кликов',
#  'click_rate': 'CR',
#  'CTR': 'CTR',
#  'unfollowed': 'Отписок',
#  'unfollow_rate': 'UR',
#  'revenue': 'Доход по атрибуции MB',
#  'orders': 'Покупок по атрибуции MB',
#  'avg_bill': 'Средний чек по атрибуции',
#  'order_conversion': 'Конверсия в заказы'}

# %%
df.loc[df.name == 'Для вас сюрприз! Откройте письмо 😉', 'Доставлено']
# Out:
# 104    2191
# Name: Доставлено, dtype: int64

# %%
z.iloc[index, 23]
# Out:
# nan

# %%
online_attr
# Out:
# {'delivered': 'Доставлено',
#  'opened': 'Открытия',
#  'open_rate': 'OR',
#  'clicked': 'Кликов',
#  'click_rate': 'CR',
#  'CTR': 'CTR',
#  'unfollowed': 'Отписок',
#  'unfollow_rate': 'UR',
#  'revenue': 'Доход по атрибуции MB',
#  'orders': 'Покупок по атрибуции MB',
#  'avg_bill': 'Средний чек по атрибуции',
#  'order_conversion': 'Конверсия в заказы'}

# %%
def get_campaign_info(df, name, column):
    """Locates specific value for named campaign"""
    try: res = df.loc[df.name == name, column].values[0]
    except: return 0
    return res
for channel in t.triggers.keys() :
    for trigger, campaign in t.triggers[channel].items():
        val = z[z.columns[0]].loc[z[z.columns[0]] == campaign].index[0]
        for (index, row), (column) in zip(z.iloc[val+1:].iterrows(), online_attr.values()):
            if pd.isnull(row[0]):
                break
            elif column == row[0]:
                val = df.loc[df.name == trigger, column].values[0]
                if 
                z.iloc[index,23] = df.loc[df.name == trigger, column].values[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-280-77cd621b9d43> in <module>
#      11                 break
#      12             elif column == row[0]:
# ---> 13                 z.iloc[index,23] = df.loc[df.name == trigger, column].values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
z

# %%
z.iloc[379,22]
# Out:
# nan

# %%
z

# %%
df = get_report('data/report/all.xlsx', 'Свод. данные (online + offline)')

# %%
# %%time
# !python dashboard.py -p 1 -r "data/report.xlsx" -o 'data/orders.csv' -c 'data/client_groups.f'
# Out:
# dashboard.py:3: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# CPU times: user 112 ms, sys: 12 ms, total: 124 ms
# Wall time: 5.96 s
