# %%
from gspread_dataframe import *
from gspread_formatting import *
import imp
import pandas as pd
import pickle as pkl
import re
import numpy as np

# %%
d = imp.load_source('dashboard', 'dashboard.py')
g = imp.load_source('gsync', 'modules/gCanvas.py')
c = imp.load_source('conf', 'config/conf.py')
r = imp.load_source('report', 'modules/reader.py')
s = imp.load_source('patch', 'modules/patcher.py')
t = imp.load_source('triggers', 'config/triggers.py')
online_attr = s.get_dictionary('config/dictionaries/online_attr.pkl')

# %%
conn = g.Connection("new test dashboard")
name = "3. Триггеры — стат. нед."
ws = conn.get_sheet_by_name(name)
gdf = get_as_dataframe(ws, index_col = 0)

# %%
df = r.get_report('all.xlsx', 0)
df = df[df.channel != 'Ручные рассылки']

# %%
patcher = s.Patcher(df, 2, 24, gdf)
# Out:
# Определите категорию кампании для 9 новых:
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> Триггер 17. Брошенная корзина с оффером:
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
# Брошенная корзина с оффером
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> NY landing 2020 DOI:
# 2
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> NY landing 2020 DOI promocode:
# 2
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> Триггер_14_ "Онлайн дешевле":
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
# Онлайн дешевле
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> Письмо с промокодом Babyblog (для новых):
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> DOI BabyBlog:
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> Персональный промокод на скидку — в письме! 🤤:
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> SMS с опросом:
# 3
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> Для вас сюрприз! Откройте письмо 😉:
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets

# %%
# Out:
# array(['номер недели', 'даты', 'Трафик на сайте', 'Регистраций', 'Email',
#        'доставлено', 'OR', 'CR', 'Выручка', 'Заказов',
#        'Заказов от трафика', 'Конверсия в заказы', nan, 'Web-push',
#        'доставлено', 'OR', 'CR', 'Выручка', 'Заказов',
#        'Заказов от трафика', 'Конверсия в заказы', nan,
#        'Сезонные триггеры ', 'доставлено', 'OR', 'CR', 'Выручка',
#        'Заказов', 'Заказов от трафика', 'Конверсия в заказы', nan,
#        'Брошенная корзина email', 'Брошенных корзин',
#        'Процент отработанных корзин', 'Доставлено', 'Открытия', 'OR',
#        'Кликов', 'CR', 'CTR', 'Отписок', 'UR', 'Доход по атрибуции MB',
#        'Отношение выручки к предыдущей неделе', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'Welcome 1 new email', 'Доставлено', 'Процент от регистраций',
#        'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок', 'UR',
#        'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'Брошенный просмотр товара email', 'Доставлено', 'Открытия', 'OR',
#        'Кликов', 'CR', 'CTR', 'Отписок', 'UR', 'Доход по атрибуции MB',
#        'Покупок по атрибуции MB', 'Средний чек по атрибуции',
#        'Конверсия в заказы', nan, 'Брошенный просмотр категории email',
#        'Доставлено', 'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок',
#        'UR', 'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'Неделя до ДР email', 'Доставлено', 'Процент от регистраций',
#        'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок', 'UR',
#        'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'Реактивация email', 'Доставлено', 'Процент от регистраций',
#        'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок', 'UR',
#        'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'Товар появился в наличии email', 'Доставлено', 'Открытия', 'OR',
#        'Кликов', 'CR', 'CTR', 'Отписок', 'UR', 'Доход по атрибуции MB',
#        'Покупок по атрибуции MB', 'Средний чек по атрибуции',
#        'Конверсия в заказы', nan, 'Напоминание о промокоде А email',
#        'Доставлено', 'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок',
#        'UR', 'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'Напоминание о промокоде В email', 'Доставлено', 'Открытия', 'OR',
#        'Кликов', 'CR', 'CTR', 'Отписок', 'UR', 'Доход по атрибуции MB',
#        'Покупок по атрибуции MB', 'Средний чек по атрибуции',
#        'Конверсия в заказы', nan, 'Отток Активные email', 'Доставлено',
#        'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок', 'UR',
#        'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'trig_water_reminder email', 'Доставлено', 'Открытия', 'OR',
#        'Кликов', 'CR', 'CTR', 'Отписок', 'UR', 'Доход по атрибуции MB',
#        'Покупок по атрибуции MB', 'Средний чек по атрибуции',
#        'Конверсия в заказы', nan, 'Напоминание о промокоде NEW_2',
#        'Доставлено', 'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок',
#        'UR', 'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'Напоминание о промокоде NEW_3', 'Доставлено', 'Открытия', 'OR',
#        'Кликов', 'CR', 'CTR', 'Отписок', 'UR', 'Доход по атрибуции MB',
#        'Покупок по атрибуции MB', 'Средний чек по атрибуции',
#        'Конверсия в заказы', nan, 'Додо Пицца', 'Доставлено', 'Открытия',
#        'OR', 'Кликов', 'CR', 'CTR', 'Отписок', 'UR',
#        'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'Мираторг + Tefal', 'Доставлено', 'Открытия', 'OR', 'Кликов', 'CR',
#        'CTR', 'Отписок', 'UR', 'Доход по атрибуции MB',
#        'Покупок по атрибуции MB', 'Средний чек по атрибуции',
#        'Конверсия в заказы', nan, 'DOI Интерактивный тест', 'Доставлено',
#        'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок', 'UR',
#        'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'DOI Интерактивный тест Спасибо', 'Доставлено', 'Открытия', 'OR',
#        'Кликов', 'CR', 'CTR', 'Отписок', 'UR', 'Доход по атрибуции MB',
#        'Покупок по атрибуции MB', 'Средний чек по атрибуции',
#        'Конверсия в заказы', nan,
#        'Пожалуйста, подтвердите подписку (Facebook Leads)', 'Доставлено',
#        'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок', 'UR',
#        'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'Ваш промокод уже здесь! (Facebook Leads)', 'Доставлено',
#        'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок', 'UR',
#        'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'Брошенная корзина Web-push', 'Брошенных корзин', 'Доставлено',
#        'Процент отработанных корзин', 'Открытия', 'OR', 'Кликов', 'CR',
#        'CTR', 'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'Брошенный просмотр товара Web-push', 'Доставлено',
#        'Процент от регистраций', 'Открытия', 'OR', 'Кликов', 'CR', 'CTR',
#        'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'Брошенный просмотр категории Web-push', 'Доставлено',
#        'Процент от регистраций', 'Открытия', 'OR', 'Кликов', 'CR', 'CTR',
#        'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'water_reminder Web-push', 'Доставлено', 'Открытия', 'OR',
#        'Кликов', 'CR', 'CTR', 'Доход по атрибуции MB',
#        'Покупок по атрибуции MB', 'Средний чек по атрибуции',
#        'Конверсия в заказы', nan, 'Товар появился в наличии Web-push',
#        'Доставлено', 'Открытия', 'OR', 'Кликов', 'CR', 'CTR',
#        'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'trig_subscribe_email Web-push', 'Доставлено', 'Открытия', 'OR',
#        'Кликов', 'CR', 'CTR', 'Доход по атрибуции MB',
#        'Покупок по атрибуции MB', 'Средний чек по атрибуции',
#        'Конверсия в заказы', nan, 'DOI Черная пятница', 'Доставлено',
#        'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок', 'UR',
#        'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'DOI Черная пятница Спасибо', 'Доставлено', 'Открытия', 'OR',
#        'Кликов', 'CR', 'CTR', 'Отписок', 'UR', 'Доход по атрибуции MB',
#        'Покупок по атрибуции MB', 'Средний чек по атрибуции',
#        'Конверсия в заказы', nan, 'DOI Елки', 'Доставлено', 'Открытия',
#        'OR', 'Кликов', 'CR', 'CTR', 'Отписок', 'UR',
#        'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'Елки Спасибо', 'Доставлено', 'Открытия', 'OR', 'Кликов', 'CR',
#        'CTR', 'Отписок', 'UR', 'Доход по атрибуции MB',
#        'Покупок по атрибуции MB', 'Средний чек по атрибуции',
#        'Конверсия в заказы', nan, 'Копия Елка SMS', 'Доставлено', nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], dtype=object)

# %%
tmp = gdf.reset_index()

# %%
list(triggers.triggers['email'].values())[0]
# Out:
# 'Брошенная корзина email'

# %%
import numpy as np

# %%
# Out:
# 31

# %%
tmp.apply(lambda x: True if x ==  else False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-300-2c4be0d7a391> in <module>
# ----> 1 tmp.apply(lambda x: True if x == list(triggers.triggers['email'].values())[0] else False)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'apply'

# %%
tmp = gdf.index.values
for channel in triggers.triggers.keys():
    tmp = list(triggers.triggers[channel].values())[0]
    print(channel, tmp[tmp.columns[0]][tmp[tmp.columns[0]] == tmp].index[0])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-294-6a2c6bf59ff9> in <module>
#       1 for channel in triggers.triggers.keys():
#       2     tmp = list(triggers.triggers[channel].values())[0]
# ----> 3     print(channel, tmp[tmp.columns[0]][tmp[tmp.columns[0]] == tmp].index[0])
#
# AttributeError: 'str' object has no attribute 'columns'

# %%
triggers = imp.load_source('triggers', 'config/triggers.py')

# %%
triggers.triggers.keys()
# Out:
# dict_keys(['email', 'wp', 'seasonal', 'sms'])

# %%
outlay=s.get_dictionary('config/dictionaries/outlay3.pkl')

# %%
outlay
# Out:
# {'email': 31, 'wp': 303, 'seasonal': 379, 'sms': 435}

# %%
def reindex_outlay(df):
    """Update start indices for each channel email/wp/seasonal/sms
    -> df: dataframe from gspread get_as_dataframe
    """
    df = df.reset_index()
    for channel in t.triggers.keys():
        trigger = list(t.triggers[channel].values())[0]
        outlay[channel] = np.where(tmp == trigger)[0][0]
    s.put_dictionary('config/dictionaries/outlay3.pkl', outlay)
#reindex_outlay(gdf)

# %%
s.get_dictionary('config/dictionaries/outlay3.pkl')
# Out:
# {'email': 31, 'wp': 303, 'seasonal': 379, 'sms': 435}

# %%
import gspread

# %%
def build_patch(df):
    """Returns df as a list of cells to patch for gspread update"""
    row=1
    col=1
    y, x = df.shape
    updates = []
    values = []
    for value_row in df.values:
        values.append(value_row)
    for y_idx, value_row in enumerate(values):
        for x_idx, cell_value in enumerate(value_row):
            updates.append(gspread.models.Cell(y_idx+row,
                                               x_idx+col,
                                               cell_value))
    return updates

# %%
#build_patch(patcher.gdf)

# %%
patc.iloc[519:,0].values
# Out:
# array(['Копия Елка SMS', 'Доставлено', 'NY landing 2020 DOI',
#        'Доставлено', 'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок',
#        'UR', 'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan,
#        'NY landing 2020 DOI promocode', 'Доставлено', 'Открытия', 'OR',
#        'Кликов', 'CR', 'CTR', 'Отписок', 'UR', 'Доход по атрибуции MB',
#        'Покупок по атрибуции MB', 'Средний чек по атрибуции',
#        'Конверсия в заказы', nan, 'SMS с опросом', 'Доставлено',
#        'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок', 'UR',
#        'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы', nan],
#       dtype=object)

# %%
mask = patcher.gdf[patcher.gdf.columns[0]].notna()
grps = pd.Series([*zip(mask.cumsum(), mask)], patcher.gdf.index)
tmp = patcher.gdf.groupby(grps).filter(lambda d: len(d) <= 2)

# %% [markdown]
# * global traffic
# * get main через named tuple
# * написать метод get_as_dataframe для gCanvas
#     * *перед удалением всех 4 групп, нужно реализовать суммы по группам*
#     * *рекурсивный обход df с печатью формата*

# %%
main_={'Доставлено':'Доставлено',
       'OR':'OR',
      'CR':'CR',
      'Доход по атрибуции MB':'Выручка',
      'Заказов':'Покупок по атрибуции MB',
      'Заказов':'Заказов от трафика',
      'Конверсия в заказы':'Конверсия в заказы',}

# %%
from collections import namedtuple
Point = namedtuple('group', [
        'Доставлено',
        'OR',
        'CR',
        'Выручка',
        'Заказов',
        'Заказов от трафика',
        'Конверсия в заказы',])
# Out:
# Доставлено
# Открытия
# OR
# Кликов
# CR
# CTR
# Отписок
# UR
# Доход по атрибуции MB
# Покупок по атрибуции MB
# Средний чек по атрибуции
# Конверсия в заказы

# %%
def get_index(chnl):
    if chnl == 'email':
        return 6
    elif chnl == 'wp':
        return 16
    elif chnl == 'seasonal':
        return 24
    else : return None

# %%
main_=[] 
for channel in t.triggers.keys():
        trigger = list(t.triggers[channel].values())[0]
        outlay[channel] = df[df.columns[0]][df[df.columns[0]] == trigger].index[0]

# %%
s.put_dictionary('config/dictionaries/outlay3.pkl', outlay)

# %%
main_={'Доставлено':'Доставлено',
       'OR':'OR',
      'CR':'CR',
      'Доход по атрибуции MB':'Выручка',
      'Заказов':'Покупок по атрибуции MB',
      'Заказов':'Заказов от трафика',
      'Конверсия в заказы':'Конверсия в заказы',}

# %%
def main_tbl_aggregator(df, attr, max_cols):
    n = 0
    res = 0
    if attr in ['Доставлено',  'Доход по атрибуции MB', 'Покупок по атрибуции MB',]:
        res+=df.loc[df.name == attr, max_cols]
    elif attr in ['OR','CR', 'Конверсия в заказы']:

# %%
z = patcher.gdf.reset_index()

# %%
def get_campaign_info(df, name, column):
    """Locates specific value for named campaign"""
    try: res = df.loc[df.name == name, column].values[0]
    except: res = 0
    return res

# %%
df = r.get_report('data/report/all.xlsx', 0)
df = df[df.channel != 'Ручные рассылки']

# %%
df.columns = df.columns.to_series().replace(online_attr)

# %%
df.columns
# Out:
# Index(['name', 'channel', 'subject', 'preview_url', 'sent', 'Доставлено',
#        'deliver_rate', 'Открытия', 'OR', 'Кликов', 'CR', 'CTR', 'Отписок',
#        'UR', 'Доход по атрибуции MB', 'Покупок по атрибуции MB',
#        'Средний чек по атрибуции', 'Конверсия в заказы'],
#       dtype='object')

# %%
online_attr
# Out:
# {'delivered': 'Доставлено',
#  'opened': 'Открытия',
#  'open_rate': 'OR',
#  'clicked': 'Кликов',
#  'click_rate': 'CR',
#  'CTR': 'CTR',
#  'unfollowed': 'Отписок',
#  'unfollow_rate': 'UR',
#  'revenue': 'Доход по атрибуции MB',
#  'orders': 'Покупок по атрибуции MB',
#  'avg_bill': 'Средний чек по атрибуции',
#  'order_conversion': 'Конверсия в заказы'}

# %%
df.loc[df.name == 'Для вас сюрприз! Откройте письмо 😉', 'Доставлено']
# Out:
# 104    2191
# Name: Доставлено, dtype: int64

# %%
z.iloc[index, 23]
# Out:
# nan

# %%
online_attr
# Out:
# {'delivered': 'Доставлено',
#  'opened': 'Открытия',
#  'open_rate': 'OR',
#  'clicked': 'Кликов',
#  'click_rate': 'CR',
#  'CTR': 'CTR',
#  'unfollowed': 'Отписок',
#  'unfollow_rate': 'UR',
#  'revenue': 'Доход по атрибуции MB',
#  'orders': 'Покупок по атрибуции MB',
#  'avg_bill': 'Средний чек по атрибуции',
#  'order_conversion': 'Конверсия в заказы'}

# %%
def get_campaign_info(df, name, column):
    """Locates specific value for named campaign"""
    try: res = df.loc[df.name == name, column].values[0]
    except: return 0
    return res
for channel in t.triggers.keys() :
    for trigger, campaign in t.triggers[channel].items():
        val = z[z.columns[0]].loc[z[z.columns[0]] == campaign].index[0]
        for (index, row), (column) in zip(z.iloc[val+1:].iterrows(), online_attr.values()):
            if pd.isnull(row[0]):
                break
            elif column == row[0]:
                val = df.loc[df.name == trigger, column].values[0]
                if 
                z.iloc[index,23] = df.loc[df.name == trigger, column].values[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-280-77cd621b9d43> in <module>
#      11                 break
#      12             elif column == row[0]:
# ---> 13                 z.iloc[index,23] = df.loc[df.name == trigger, column].values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
z

# %%
z.iloc[379,22]
# Out:
# nan

# %%
z

# %%
df = get_report('data/report/all.xlsx', 'Свод. данные (online + offline)')

# %%
# %%time
# !python dashboard.py -p 1 -r "data/report.xlsx" -o 'data/orders.csv' -c 'data/client_groups.f'
# Out:
# dashboard.py:3: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# CPU times: user 112 ms, sys: 12 ms, total: 124 ms
# Wall time: 5.96 s
