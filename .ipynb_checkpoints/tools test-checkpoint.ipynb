# %%
from gspread_dataframe import *
from gspread_formatting import *
import imp
import pandas as pd
import pickle as pkl
import re
import numpy as np

# %%
d = imp.load_source('dashboard', 'dashboard.py')
g = imp.load_source('gsync', 'modules/gCanvas.py')
c = imp.load_source('conf', 'config/conf.py')
r = imp.load_source('report', 'modules/reader.py')
s = imp.load_source('patch', 'modules/patcher.py')
t = imp.load_source('triggers', 'config/triggers.py')

# %%
conn = g.Connection("new test dashboard")
name = "3. Триггеры — стат. нед."
ws = conn.get_sheet_by_name(name)
gdf = get_as_dataframe(ws, index_col = 0)

# %%
df = r.get_report('all.xlsx', 0)
df = df[df.channel != 'Ручные рассылки']

# %%
patcher = s.Patcher(df, 2, 24, gdf)
# Out:
# Определите категорию кампании для 9 новых:
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> Триггер 17. Брошенная корзина с оффером:
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
# Брошенная корзина с оффером
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> NY landing 2020 DOI:
# 2
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> NY landing 2020 DOI promocode:
# 2
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> Триггер_14_ "Онлайн дешевле":
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
# Онлайн дешевле
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> Письмо с промокодом Babyblog (для новых):
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> DOI BabyBlog:
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> Персональный промокод на скидку — в письме! 🤤:
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> SMS с опросом:
# 3
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> Для вас сюрприз! Откройте письмо 😉:
#
# Нажмите только 'Enter', если название компании Вас устраивает:
# Введите новое название для отображения в Google Sheets

# %%
from collections import namedtuple as nt
from gspread_formatting import *

# %%
def create_format_dict(*args):
    fmt = nt('fmt', ['bold',
                     'italic',
                     'alignment',
                     'background'])
    return fmt(*args)

main = create_format_dict(True, False, 'left', color(244, 204, 204))
email = create_format_dict(True, True, 'left', color(255, 242, 204))
wp = create_format_dict(True, True, 'left', color(208, 224, 227))
seasonal = create_format_dict(True, True, 'left', color(217, 210, 233))
sms = create_format_dict(True, True, 'left', color(201, 218, 248))
ord_conv = create_format_dict(True, False, 'right', color(201, 218, 248))

main_idx = ['Email', 'Web-push', 'Сезонные триггеры']
email_idx = s.get_dict_value('triggers.pkl', 2)['email'].values()
wp_idx = s.get_dict_value('triggers.pkl', 2)['wp'].values()
seasonal_idx = s.get_dict_value('triggers.pkl', 2)['seasonal'].values()
sms_idx = s.get_dict_value('triggers.pkl', 2)['sms'].values()
ord_idx = ['Конверсия в заказы']

formats = [(main,     main_idx),
           (email,    email_idx),
           (wp,       wp_idx),
           (seasonal, seasonal_idx),
           (sms,      sms_idx),
           (ord_conv, ord_idx),]

# %%
def get_format_patch(fmt_):
    def get_cell_format(_fmt):
        return cellFormat(backgroundColor=_fmt.background,
               textFormat=textFormat(bold=_fmt.bold, italic=_fmt.italic),
                          horizontalAlignment=_fmt.alignment.upper())

    def get_fmt_ranges(df, row_vals, max_cols):
        def get_rows_to_a1(df, values, col):
            def locate_formats(series, row_val):
                return np.where(series == row_val)[0][0] + 2
            indices = [locate_formats(df.iloc[:, 0], x) for x in values]
            return [rowcol_to_a1(x, col) for x in indices]

        minr = get_rows_to_a1(df, row_vals, 1)
        maxr = get_rows_to_a1(df, row_vals, max_cols)
        ranges = []
        for x, y in zip(minr, maxr):
            ranges.append(x + ':' + y)
        return ranges

    patch = []
    (key, val) = fmt_
    return patch.append((get_cell_format(key), get_fmt_ranges(df, val, limit)))

# %%
def get_cell_format(_fmt):
    return cellFormat(backgroundColor=_fmt.background,
           textFormat=textFormat(bold=_fmt.bold, italic=_fmt.italic),
                      horizontalAlignment=_fmt.alignment.upper())

def get_fmt_ranges(df, row_vals, max_cols):
    def get_rows_to_a1(df, values, col):
        def locate_formats(series, row_val):
            return np.where(series == row_val)[0][0] + 2
        indices = [locate_formats(df.iloc[:, 0], x) for x in values]
        return [rowcol_to_a1(x, col) for x in indices]

    minr = get_rows_to_a1(df, row_vals, 1)
    maxr = get_rows_to_a1(df, row_vals, max_cols)
    ranges = []
    for x, y in zip(minr, maxr):
        ranges.append(x + ':' + y)
    return ranges

# %%
patches = []
for fmt_ in formats:
    (key, val) = fmt_
    patches.append((get_cell_format(key), get_fmt_ranges(patcher.gdf, val, patcher.limit)))

# %%
(key, val) = formats[0]

# %%
get_fmt_ranges(patcher.gdf, val, patcher.limit)
# Out:
# ['A6:X6', 'A15:X15', 'A24:X24']

# %%
patch = []
(key, val) = fmt_

# %%
def build_format_patch(df, limit):
    """Returns new formats for gspread worksheet"""
    def get_format_patch(fmt_):
        def get_cell_format(_fmt):
            return cellFormat(backgroundColor=_fmt.background,
                   textFormat=textFormat(bold=_fmt.bold, italic=_fmt.italic),
                              horizontalAlignment=_fmt.alignment.upper())

        def get_fmt_ranges(df, row_vals, max_cols):
            def get_rows_to_a1(df, values, col):
                def locate_formats(series, row_val):
                    return np.where(series == row_val)[0][0] + 2
                indices = [locate_formats(df.iloc[:, 0], x) for x in values]
                return [rowcol_to_a1(x, col) for x in indices]

            minr = get_rows_to_a1(df, row_vals, 1)
            maxr = get_rows_to_a1(df, row_vals, max_cols)
            ranges = []
            for x, y in zip(minr, maxr):
                ranges.append(x + ':' + y)
            return ranges

        patch = []
        (key, val) = fmt_
        return patch.append((get_cell_format(key), get_fmt_ranges(df, val, limit)))
    return [get_format_patch(fmt) for fmt in formats]

# %%
# Out:
# [None, None, None, None, None, None]

# %%
build_format_patch(patcher.gdf, patcher.limit)
# Out:
# [None, None, None, None, None, None]

# %%
df = get_report('data/report/all.xlsx', 'Свод. данные (online + offline)')

# %%
# !python dashboard.py -p 1 -r "all.xlsx" -o 'orders.csv'
# Out:
# dashboard.py:3: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# Определите категорию кампании для 9 новых:
#
# Нажмите 'Enter' для Email
# 	'1' для Web-push
# 	'2' для сезонной
# 	'3' для SMS
#
# -> Триггер 17. Брошенная корзина с оффером:
# ^C
# Traceback (most recent call last):
#   File "dashboard.py", line 81, in <module>
#     d.run_all()
#   File "dashboard.py", line 63, in run_all
#     self.upload_data()
#   File "dashboard.py", line 56, in upload_data
#     patch_wrapper(sheet, data, self.connector, 'x', gdf)
#   File "dashboard.py", line 45, in patch_wrapper
#     sheet.update_batch(s.Patcher(df, sheets.get(name), sheet.max_cols, gdf).patch)
#   File "modules/patcher.py", line 36, in __init__
#     self.patch = self.switch()
#   File "modules/patcher.py", line 40, in switch
#     return getattr(self, self.methods[self.type])()
#   File "modules/patcher.py", line 79, in get_campaigns_online
#     create_new_campaigns(self.gdf, new_campaigns, self.limit - 1)
#   File "modules/patcher.py", line 70, in create_new_campaigns
#     seasonal, sms, self.t, self.type)
#   File "modules/tab3.py", line 58, in check_new_groups
#     v = input('-> ' + new_campaigns[i] + ': \n')
# KeyboardInterrupt

# %%
s.get_dict_value('triggers.pkl', 1).get('Число ПОКУПАТЕЛЕЙ в ЭГ за период')
# Out:
# 'id_cli'
